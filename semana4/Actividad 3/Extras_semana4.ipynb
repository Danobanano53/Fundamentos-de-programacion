# %% [markdown]
# ## Suma de todos lo elemnos de una matriz

# %%
tabla = [
    [1, 2, 3],
    [4, 5, 6],
    [7 ,8, 8]
]

def imprimir_tabla(tabla):
    for fila in tabla:
        for numero in fila:
            print(numero, end=" ")

    print()



def suma_tabla(tabla):
    suma = 0
    for fila in tabla:
        for numero in fila:
            suma += numero
    return suma   

imprimir_tabla(tabla)

resultado = suma_tabla(tabla)
print(f"la suma de los numeros en la matriz es: {resultado}")
# Out:
# 1 2 3 4 5 6 7 8 8
# la suma de los numeros en la matriz es: 44

# %% [markdown]
# ## Funcion suma fila

# %%
tabla = [
    [4, 6, 7],
    [8, 2, 5],
    [7, 8, 1]
]

def imprimir_tabla(tabla):
    for fila in tabla:
        for numero in fila:
            print(numero, end=" ")
        print()
def suma_fila1(tabla):
    suma = 0
    for numero in tabla[0]:
        suma += numero
    return suma
def suma_fila2(tabla):
    suma = 0
    for numero in tabla[1]:
        suma += numero
    return suma
def suma_fila3(tabla):
    suma = 0
    for numero in tabla[2]:
        suma += numero
    return suma

imprimir_tabla(tabla)
print(f"la suma de la fila 1 es: {suma_fila1(tabla)}")
print(f"la suma de las fila 2 es: {suma_fila2(tabla)}")
print(f"la suma de la fila 3 es: {suma_fila3(tabla)}")
# Out:
# 4 6 7
# 8 2 5
# 7 8 1
# la suma de la fila 1 es: 17
# la suma de las fila 2 es: 15
# la suma de la fila 3 es: 16

# %% [markdown]
# ## Tabla pitagoras tamaño variable

# %%
rango = int(input("Ingrese el numero de rango: "))

tabla = []

for i in range(1, rango + 1):

    fila = []

    for j in range(1, rango + 1):

        resultado = i * j

        fila.append(resultado)

    tabla.append(fila)


def imprimir_tabla(tabla):

    for fila in tabla:

        for numero in fila:

            print(numero, end="\t")

        print()


def buscar_coordenada(tabla, fila, columna):

    resultado = tabla[fila - 1][columna - 1]

    return resultado


imprimir_tabla(tabla)


fila = int(input(f"Ingrese el primer factor (1 al {rango}): "))

columna = int(input(f"Ingrese el segundo factor (1 al {rango}): "))


producto = buscar_coordenada(tabla, fila, columna)


print(fila, "x", columna, "=", producto)
# Out:
# 1	2	3	4	5	6
# 2	4	6	8	10	12
# 3	6	9	12	15	18
# 4	8	12	16	20	24
# 5	10	15	20	25	30
# 6	12	18	24	30	36
# 4 x 2 = 6
