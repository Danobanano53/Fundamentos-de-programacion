# %% [markdown]
# # sesion1
# Este archivo es para 2 cosas:
#  1. familiarizarme con jupyter notebook
#  2. practicar python

# %%
print("holiwis")
# Out:
# holiwis

# %% [markdown]
# ## variables
# las variables en python son tipos de datos que tienen diferente forma
#
# -numericas
#      -enteros
#      -flotante
# -cadenas dencaracteres
# -booleanos
# -compuestos

# %%
nombre = "Dano"
edad = 19
es_estudiante = True
esta_activo = None

print(type(nombre))
print(type(edad))
print(type(es_estudiante))
print(type(esta_activo))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'NoneType'>

# %%
nombre = "dano"
edad = 19

print("hola", nombre, "ya vi que tienes", edad, "años")
# Out:
# hola dano ya vi que tienes 19 años

# %% [markdown]
# Este punto inicie git

# %% [markdown]
# ## algoritmo para calcular velocidad

# %%
distancia = int(input("ingresa la distancia: "))
tiempo = int(input("ingresa el tiempo: "))
velocidad = distancia / tiempo
print("la velocidad es:", velocidad)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 distancia = int(input("ingresa la distancia: "))
#       2 tiempo = int(input("ingresa el tiempo: "))
#       3 velocidad = distancia / tiempo
#       4 print("la velocidad es:", velocidad)
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ## operadores

# %%
a = 10
b = 5
print (a == b)
# Out:
# False

# %% [markdown]
# ## edad

# %%
nombre = input("ingresa tu nombre: ")
edad = int(input("ingresa tu edad: "))
print("hola", nombre, "ya vi que tienes", edad, "años")
# Out:
# hola dano ya vi que tienes 29 años

# %% [markdown]
# ## conversor de temperatura

# %%
celsius = float(input("ingresa la temperatura en celsius: "))
fahrenheit = (celsius * 9/5) + 32
kelvin = celsius + 273.15
print("la temperatura en fahrenheit es:", fahrenheit)
print("la temperatura en kelvin es:", kelvin)
# Out:
# la temperatura en fahrenheit es: 113.0
# la temperatura en kelvin es: 318.15

# %% [markdown]
# ## CALIFICACION

# %%
cal1 = float(input("ingresa la calificacion 1: "))
cal2 = float(input("ingresa la calificacion 2: "))
cal3 = float(input("ingresa la calificacion 3: "))
promedio = (cal1 + cal2 + cal3) / 3
print("el promedio es:", f"{promedio:.2f}")
print("me estrese mucho haciendo este programa, pero lo logre")
# Out:
# el promedio es: 4.33
# me estrese mucho haciendo este programa, pero lo logre

# %% [markdown]
# ## convertir kilometros a millas

# %%
kilometros = float(input("ingresa la distancia en kilometros: "))
millas = kilometros * 0.621371
print("la distancia en millas es:", f"{millas:.2f}")
# Out:
# la distancia en millas es: 124.27

# %% [markdown]
# ## pelicula para mayores de 18

# %%
nombre = input("ingresa tu nombre: ")
edad = int(input("ingresa tu edad: "))
if edad >= 18:
    print("hola", nombre, "usted puede pasar a ver la pelicula, disfrute")
else:
    print("hola", nombre, "lo sentimos usted no puede pasar a ver la pelicula :( ")
# Out:
# hola dano lo sentimos usted no puede pasar a ver la pelicula :(

# %% [markdown]
# ## Calculadora de edad

# %%
año = int(input("ingresa tu año de nacimiento: "))
año_actual = int(input("ingresa el año actual: "))
edad = (año_actual - año)

print ("tienes", edad, "años")
# Out:
# tienes 19 años

# %% [markdown]
# ## precio con descuento

# %%
precio = float(input("ingresa el precio del producto: "))
descuento = 10

precio_final = precio - (precio * descuento / 100)
print("el precio final con descuento es:", f"{precio_final:.2f}")
# Out:
# el precio final con descuento es: 1116.00

# %% [markdown]
# ## perimetro de un cuadrado

# %%
print ("vamos a sacar el perimetro de un cuadrado")
lado = float(input("ingresa la medida del lado : "))
perimetro = lado * 4
print(f"el resultado es: {perimetro:.2f}")
# Out:
# vamos a sacar el perimetro de un cuadrado
# el resultado es: 180.00
