# %% [markdown]
# ## SEMANA7

# %%
archivo = open("saludo.txt", mode="a")
archivo.write("estl es una mas tercera linea\n")
archivo.close()
print("Archivo creado correctamente")
# Out:
# Archivo creado correctamente

# %%
archivo = open("notas.txt", mode="w")
archivo.write("esto es una primera linea\n")
archivo.write("esto es una segunda linea\n")
archivo.close
# Out:
# <function TextIOWrapper.close()>

# %%
with open("bitacora.txt", mode="w") as archivo:
    archivo.write("esto es una primera lista\n")
    archivo.write("esto es una segunda linea\n")
    archivo.write("esto es una tercer linea\n")

with open("bitacora.txt", mode="a") as archivo:
    archivo.write("esto es una cuarta linea\n")

# %%
nombre = input("ingrese su nombre: ")
edad = input("ingrese su edad: ")

with open("datos_usuario.txt", mode="w") as archivo:
    archivo.write(f"Nombre: {nombre}, Edad: {edad}")
print("datos guardados")
# Out:
# datos guardados

# %% [markdown]
# ## lectura

# %%
with open("LCQ.txt", mode="r") as a:
    contenido = a.read()
    print(contenido)
# Out:
# habia una vez una computadora que se apagaba
# cuando no obtenia corriente electrica
# Fin. U w U

# %%
nombre = input("Ingresa tu nombre: ")
edad = input("Ingresa tu edad: ")

with open("datos_usuario.txt", "w") as archivo:
    archivo.write(f"Nombre: {nombre}, Edad: {edad}\n")

print("Datos guardados en datos_usuario.txt.")
# Out:
# Datos guardados en datos_usuario.txt.

# %%
with open("poema.txt", "r") as archivo:
    linea1 = archivo.readline()
    linea2 = archivo.readline()

print("Primera linea:", linea1.strip())
print("Segunda linea:", linea2.strip())
# Out:
# Primera linea: habia una vez una computadora que se apagaba
# Segunda linea: cuando no obtenia corriente electrica

# %%
with open("poema.txt", "r") as archivo:
    lineas = archivo.readlines()

print("Total de lineas:", len(lineas))
for i, linea in enumerate(lineas, 1):
    print(f"{i}: {linea.strip()}")
# Out:
# Total de lineas: 3
# 1: habia una vez una computadora que se apagaba
# 2: cuando no obtenia corriente electrica
# 3: Fin. U w U

# %%
with open("poema.txt", "r") as archivo:
    for linea in archivo:
        print(linea.strip())
# Out:
# habia una vez una computadora que se apagaba
# cuando no obtenia corriente electrica
# Fin. U w U

# %%
with open("ventas.txt", "r") as archivo:
    montos = [float(linea.strip()) for linea in archivo]


total = sum(montos)



with open("resumen.txt", "w") as archivo:
    archivo.write(f"Total de ventas: {total:.2f}\n")
    archivo.write(f"Promedio por venta: {promedio:.2f}\n")


with open("resumen.txt", "r") as archivo:
    print(archivo.read())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 11
#       7
#       8
#       9 with open("resumen.txt", "w") as archivo:
#      10     archivo.write(f"Total de ventas: {total:.2f}\n")
# ---> 11     archivo.write(f"Promedio por venta: {promedio:.2f}\n")
#      12
#      13
#      14 with open("resumen.txt", "r") as archivo:
#
# NameError: name 'promedio' is not defined

# %%
import time
def barra_de_carga():
    for i in range(11):
        porcentaje = i * 10
        barra = "#" * i + "-" * (10 - i)
        time.sleep(0.2)
        



        #print(f"\r[{barra}] {porcentaje}%", end="")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       5         barra = "#" * i + "-" * (10 - i)
#       6         time.sleep(0.2)
#       7
#       8
# ----> 9 print(barra_de_carga(print(f"\r[{barra}] {porcentaje}%", end="")))
#      10
#      11
#      12         #print(f"\r[{barra}] {porcentaje}%", end="")
#
# NameError: name 'barra' is not defined
