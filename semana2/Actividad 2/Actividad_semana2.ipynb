# %% [markdown]
# ## Entrada al museo

# %%
cantidad = int(input("ingresa la cantidad de visitantes: "))

visitantes = []

i = 0


while i < cantidad:
   edad = int(input("ingrese la edad del  visitante: "))
   if edad < 0:
          print("edad no valida")
          continue
   elif edad <  3:
          precio = 0
   elif edad <= 17:
           precio = 30
   else:
          precio = 45

   tipo = input("ingresa el tipo de visitante(adulto_mayor, profesor, estudiante, otro): ")

   if tipo == "adulto_mayor":
    descuento = 0.12
   elif tipo == "profesor":
      descuento = 0.10
   elif tipo == "estudiante":
      descuento = 0.10
   else:
      descuento = 0

   precio_descuento = precio * descuento

   precio_final = precio - precio_descuento

   visitantes.append([edad, precio, tipo, descuento, precio_final ])

   i = i + 1
total = 0
for visitante in visitantes:
    print("Edad:", visitante[0])
    print("precio base:$", visitante[1])
    print("tipo de visitante:", visitante[2])
    print("descuento: %", visitante[3])
    print("precio final: $", visitante[4])
    
    total += visitante[4]
    
print("total final a pagar:$", total)
# Out:
# Edad: 45
# precio base:$ 45
# tipo de visitante: profesor
# descuento: % 0.1
# precio final: $ 40.5
# total final a pagar:$ 40.5

# %% [markdown]
# ## Estadistica de visitantes con for

# %%
cantidad = int(input("Ingresa la cantidad de visitantes: "))
adultos = 0
suma = 0

for i in range(cantidad):
    edad = int(input("ingresa la edad: "))

    print(f"visitante {i + 1}: {edad} años")
    if edad >= 18:
        adultos = adultos + 1


    suma += edad

    promedio = suma / cantidad
print(f"promedio de edad es: {promedio:.2f}")

print(f"cantidad de visitantes: {cantidad}")

print(f"la cantidad de adultos es: {adultos}")
# Out:
# visitante 1: 45 años
# visitante 2: 56 años
# visitante 3: 56 años
# promedio de edad es: 52.33
# cantidad de visitantes: 3
# la cantidad de adultos es: 3

# %% [markdown]
# ## Piramide

# %%
for i in range(1,30):
    print("*" * i)

print()
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********
# ***********
# ************
# *************
# **************
# ***************
# ****************
# *****************
# ******************
# *******************
# ********************
# *********************
# **********************
# ***********************
# ************************
# *************************
# **************************
# ***************************
# ****************************
# *****************************
